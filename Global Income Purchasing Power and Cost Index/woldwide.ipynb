# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('worldwide.csv', index_col='Rank')
data.head()
# Out:
#                   Country/Region  Cost index Ø Monthly income  \
# Rank
# 1                      Bermuda *       157.9       10,437 USD
# 2               Cayman Islands *       138.3        5,433 USD
# 3                    Switzerland       131.4        7,454 USD
# 4     Turks and Caicos Islands *       124.6        2,013 USD
# 5                         Israel       123.1        4,554 USD
#
#       Purchasing power index
# Rank
# 1                      103.8
# 2                       61.7
# 3                       89.1
# 4                       25.4
# 5                       58.1

# %% [markdown]
# Here's a description of each of the columns:
#
# Rank: This column represents the ranking of countries or regions based on a specific criterion, which is not explicitly mentioned in the column name. The rank could be related to the overall cost of living, quality of life, economic indicators, or any other relevant metric. Lower ranks typically indicate better performance or lower costs, depending on the context.
#
# Country/Region: This column contains the names of the countries or regions being analyzed in the dataset. Each row corresponds to a specific country or region, and this column serves as the identifier for each data point.
#
# Cost Index: The cost index column provides a numerical value that quantifies the cost of living in each country or region. A higher cost index value indicates that living expenses, such as housing, food, transportation, and other essentials, are relatively high in that particular location. Conversely, a lower cost index suggests a more affordable cost of living.
#
# Ø Monthly Income: This column represents the average monthly income for residents of each country or region. It provides insight into the earning potential and income levels of the population in different areas. A higher monthly income typically suggests greater financial resources for residents.
#
# Purchasing Power Index: The purchasing power index column measures the relative purchasing power of the population in each country or region. It indicates how far a given income will go in terms of buying goods and services in that location. A higher purchasing power index suggests that the population can afford a relatively higher standard of living, while a lower index implies reduced purchasing power.

# %% [markdown]
# # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 1 to 101
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          101 non-null    object
#  1   Cost index              101 non-null    float64
#  2   Ø Monthly income        101 non-null    object
#  3   Purchasing power index  101 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 3.9+ KB

# %%
data.columns
# Out:
# Index(['Country/Region', 'Cost index', 'Ø Monthly income',
#        'Purchasing power index'],
#       dtype='object')

# %%
data = data.rename(columns={'Ø Monthly income':'Monthly income'})

# %%
data.columns
# Out:
# Index(['Country/Region', 'Cost index', 'Monthly income',
#        'Purchasing power index'],
#       dtype='object')

# %%
def Monthly_income_to_number(x):
    y = ''
    for i in x:
        if i.isnumeric():
            y = y + i
    return float(y)

# %%
data['Monthly income'] = data['Monthly income'].map(Monthly_income_to_number)

# %%
data['Monthly income']
# Out:
# Rank
# 1      10437.0
# 2       5433.0
# 3       7454.0
# 4       2013.0
# 5       4554.0
#         ...
# 97       101.0
# 98       132.0
# 99       101.0
# 100      183.0
# 101      384.0
# Name: Monthly income, Length: 101, dtype: float64

# %%
def Country_Region_clean(x):
    if x[-2:] == ' *':        
        return x[:-2]
    return x

# %%
data['Country/Region'] = data['Country/Region'].map(Country_Region_clean)

# %%
data['Country/Region']
# Out:
# Rank
# 1                       Bermuda
# 2                Cayman Islands
# 3                   Switzerland
# 4      Turks and Caicos Islands
# 5                        Israel
#                  ...
# 97                   Tajikistan
# 98                     Pakistan
# 99                      Myanmar
# 100                  Uzbekistan
# 101                   Palestine
# Name: Country/Region, Length: 101, dtype: object

# %%
sns.barplot(data=data.sort_values(by='Cost index', ascending=False).head(20), x='Cost index', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data=data.sort_values(by='Cost index', ascending=False).tail(20), x='Cost index', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data=data.sort_values(by='Monthly income', ascending=False).head(20), x='Monthly income', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data=data.sort_values(by='Monthly income', ascending=False).tail(20), x='Monthly income', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data=data.sort_values(by='Purchasing power index', ascending=False).head(20), x='Purchasing power index', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data=data.sort_values(by='Purchasing power index', ascending=False).tail(20), x='Purchasing power index', y='Country/Region')
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# # Quality of Life Index Calculation Process

# %%
from sklearn.preprocessing import MinMaxScaler

X = data.loc[:,['Cost index', 'Monthly income', 'Purchasing power index', 'Country/Region']]
scaler = MinMaxScaler()
X[['Cost index', 'Monthly income', 'Purchasing power index']] = scaler.fit_transform(X[['Cost index', 'Monthly income', 'Purchasing power index']])
X
# Out:
#       Cost index  Monthly income  Purchasing power index  \
# Rank
# 1       1.000000        1.000000                0.775368
# 2       0.860200        0.515914                0.449264
# 3       0.810984        0.711425                0.661503
# 4       0.762482        0.185063                0.168087
# 5       0.751783        0.430879                0.421379
# ...          ...             ...                     ...
# 97      0.041369        0.000097                0.023238
# 98      0.038516        0.003096                0.040279
# 99      0.035663        0.000097                0.025562
# 100     0.028531        0.008029                0.073586
# 101     0.000000        0.027474                0.236251
#
#                 Country/Region
# Rank
# 1                      Bermuda
# 2               Cayman Islands
# 3                  Switzerland
# 4     Turks and Caicos Islands
# 5                       Israel
# ...                        ...
# 97                  Tajikistan
# ...

# %%
weight_cost_index = 0.4
weight_monthly_income = 0.3
weight_purchasing_power = 0.3

# %%
X['quality_of_life_index'] = (weight_cost_index * X['Cost index']) + \
                               (weight_monthly_income * X['Monthly income']) + \
                               (weight_purchasing_power * X['Purchasing power index'])

# %%
X = X.sort_values(by='quality_of_life_index', ascending=False)

# %%
X['quality_of_life_index'] = round(X['quality_of_life_index'],3 )

# %%
X.head(20)
# Out:
#       Cost index  Monthly income  Purchasing power index  Country/Region  \
# Rank
# 1       1.000000        1.000000                0.775368         Bermuda
# 10      0.644793        0.760279                0.867545          Norway
# 3       0.810984        0.711425                0.661503     Switzerland
# 14      0.611270        0.725549                0.865995      Luxembourg
# 8       0.662625        0.643901                0.714950         Ireland
# 17      0.587019        0.605979                0.745933   United States
# 2       0.860200        0.515914                0.449264  Cayman Islands
# 9       0.652639        0.580439                0.651433         Denmark
# 7       0.730385        0.540292                0.546863         Iceland
# 33      0.369472        0.558673                1.000000           Qatar
# 32      0.388017        0.532069                0.916344       Singapore
# 20      0.543509        0.498114                0.652208          Sweden
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(data=X.head(20), x = 'quality_of_life_index', y = 'Country/Region')
ax.bar_label(ax.containers[0])
plt.xlabel('Índice de calidad de vida')
plt.ylabel('País/región')
plt.title('20 países con el índice de calidad de vida más alto')
plt.show()
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(data=X.tail(20), x = 'quality_of_life_index', y = 'Country/Region')
ax.bar_label(ax.containers[0])
plt.xlabel('Índice de calidad de vida')
plt.ylabel('País/región')
plt.title('20 países con el índice de calidad de vida más bajo')
plt.show()
# Out:
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\yamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
