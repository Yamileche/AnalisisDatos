# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Clean Data_pakwheels.csv')
data = data.drop("Unnamed: 0", axis=1)

# %% [markdown]
# # Exploración de datos

# %%
data.head()
# Out:
#   Company Name Model Name    Price  Model Year   Location  Mileage
# 0       Toyota       Vitz  2385000        2017  Islamabad     9869  \
# 1       Toyota    Corolla   111000        2019        KPK    11111
# 2       Suzuki       Alto  1530000        2019        KPK    17500
# 3       Suzuki       Alto  1650000        2019     Punjab     9600
# 4       Toyota    Corolla  1435000        2010  Islamabad   120000
#
#   Engine Type  Engine Capacity   Color  Assembly  Body Type Transmission Type
# 0      Petrol             1000  Silver  Imported  Hatchback         Automatic  \
# 1      Petrol             1300   White     Local      Sedan         Automatic
# 2      Petrol              660   White     Local  Hatchback         Automatic
# 3      Petrol              660   White     Local  Hatchback            Manual
# 4      Petrol             1300   Black     Local      Sedan            Manual
#
#   Registration Status
# 0       Un-Registered
# 1          Registered
# 2       Un-Registered
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46022 entries, 0 to 46021
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company Name         46022 non-null  object
#  1   Model Name           46022 non-null  object
#  2   Price                46022 non-null  int64
#  3   Model Year           46022 non-null  int64
#  4   Location             46022 non-null  object
#  5   Mileage              46022 non-null  int64
#  6   Engine Type          46022 non-null  object
#  7   Engine Capacity      46022 non-null  int64
#  8   Color                46022 non-null  object
#  9   Assembly             46022 non-null  object
#  10  Body Type            46022 non-null  object
#  11  Transmission Type    46022 non-null  object
#  12  Registration Status  46022 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 4.6+ MB

# %% [markdown]
# **Id**: A unique identifier for each car listing.
#
# **Price**: The price range of the cars, with specific price labels and counts.
#
# **Company Name**: The name of the car manufacturing company, with percentages of each company's representation.
#
# **Model** **Name**: The model name of the cars, with percentages of each model's representation.
#
# **Model** **Year**: The range of car manufacturing years, with counts and percentages.
#
# **Location**: The location of the cars, specifying the regions where they are available for purchase, along with their percentages.
#
# **Mileage**: Information on the mileage of the cars, with mileage ranges, counts, and percentages.
#
# **Engine** Type: Descriptions of the engine types, with percentages for each type.
#
# **Engine** Capacity: Engine capacity ranges with counts and percentages.
#
# **Color**: The color distribution of the cars, with percentages for each color.
#
# This dataset, containing 46,000 valid entries, offers valuable insights into the used car market, including pricing, manufacturer representation, model availability, and various specifications such as model year, location, mileage, engine type, engine capacity, and color preferences. It can be a valuable resource for analyzing and understanding trends in the used car industry.

# %%
data.describe()
# Out:
#               Price    Model Year        Mileage  Engine Capacity
# count  4.602200e+04  46022.000000   46022.000000     46022.000000
# mean   2.014153e+06   2011.035374   90965.128243      1313.115575
# std    2.939071e+06      6.399403   63656.656034       614.690832
# min    1.110000e+05   1990.000000       1.000000        16.000000
# 25%    8.500000e+05   2007.000000   48899.500000      1000.000000
# 50%    1.450000e+06   2013.000000   80000.000000      1300.000000
# 75%    2.300000e+06   2016.000000  120000.000000      1500.000000
# max    7.750000e+07   2019.000000  999999.000000      6600.000000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Model Year'}>],
#        [<Axes: title={'center': 'Mileage'}>,
#         <Axes: title={'center': 'Engine Capacity'}>]], dtype=object)

# %%
mostPopularComp = list(data['Company Name'].value_counts().index[:10])
mostPopularComp
# Out:
# ['Suzuki',
#  'Toyota',
#  'Honda',
#  'Daihatsu',
#  'Nissan',
#  'Mitsubishi',
#  'Mercedes',
#  'Hyundai',
#  'Audi',
#  'FAW']

# %%
plt.figure(figsize=(10,8))
dataAux=data['Company Name'].value_counts(ascending=False).head(10)
sns.barplot(y = dataAux.index, x = dataAux, palette='deep').set(ylabel='Compañía', xlabel='Número de autos')
plt.title('Cantidad de autos por compañía')
# Out:
# Text(0.5, 1.0, 'Cantidad de autos por compañía')

# %%
sns.countplot(x = 'Transmission Type', data=data)
# Out:
# <Axes: xlabel='Transmission Type', ylabel='count'>

# %%
sns.countplot(x = 'Registration Status', data=data)
# Out:
# <Axes: xlabel='Registration Status', ylabel='count'>

# %%
dataAux = data.Color.value_counts(ascending=False).head(20)
sns.barplot(y = dataAux.index, x = dataAux, palette='deep').set(ylabel='Color', xlabel='Número de autos')
plt.title('Cantidad de autos por color')
# Out:
# Text(0.5, 1.0, 'Cantidad de autos por color')

# %%
sns.countplot(x = 'Engine Type', data=data)
# Out:
# <Axes: xlabel='Engine Type', ylabel='count'>

# %%
sns.countplot(x = 'Body Type', data=data)
# Out:
# <Axes: xlabel='Body Type', ylabel='count'>

# %%
sns.countplot(x = 'Location', data=data)
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
dataAux = data[(data['Price']<8000000) & (data['Company Name'].isin(mostPopularComp))]
plt.figure(figsize=(10,4))
sns.histplot(x = 'Price', data=dataAux, palette='bright').set(xlabel='Precio', ylabel='')
plt.title('Histograma de precio')
# Out:
# /tmp/ipykernel_33097/1272962690.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x = 'Price', data=dataAux, palette='bright').set(xlabel='Precio', ylabel='')
# Text(0.5, 1.0, 'Histograma de precio')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Suponiendo que ya tienes tus datos y mostPopularComp definidos

# Crear subfiguras compartiendo el eje x
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(20, 10), sharex='col')

i = 0
for col in range(2):
    for row in range(5):
        dataAux = data[(data['Price'] < 8000000) & (data['Company Name'] == mostPopularComp[i])]
        
        # Calcular el ancho de las barras (puedes ajustar este valor según tus preferencias)
        binwidth = 50000
        
        ax = sns.histplot(x='Price', data=dataAux, hue='Company Name', palette='bright', 
                          ax=axes[row, col], binwidth=binwidth, edgecolor='black', legend=False)
        
        # Quitar etiqueta del eje x
        axes[row, col].set_xlabel('Precio')
        axes[row, col].set_ylabel('')
        # Añadir una leyenda personalizada
        axes[row, col].legend(title='', labels=[mostPopularComp[i]])
        
        i += 1

        

fig.suptitle('Histograma de precio de autos por cada compañía')
plt.tight_layout()
plt.show()

# %%
dataAux = data[data['Mileage']<500000]
plt.figure(figsize=(10,4))
sns.histplot(x = 'Mileage', data=dataAux)
# Out:
# <Axes: xlabel='Mileage', ylabel='Count'>

# %%
data.groupby(['Color', 'Company Name']).size()
# Out:
# Color     Company Name
# Assembly  Audi              2
#           BMW               2
#           Chevrolet         2
#           Daewoo            2
#           Daihatsu        137
#                          ...
# Yellow    Hyundai           1
#           Mazda             2
#           Mitsubishi        3
#           Suzuki           24
#           Toyota           22
# Length: 330, dtype: int64

# %%
data.groupby(['Model Year','Company Name']).size()
# Out:
# Model Year  Company Name
# 1990        BMW                2
#             Honda              8
#             Mitsubishi        29
#             Nissan             9
#             Suzuki            80
#                             ...
# 2019        Nissan             2
#             Range              1
#             Suzuki          1385
#             Toyota           657
#             United            64
# Length: 387, dtype: int64

# %%
sns.countplot(data = data[data['Model Year'] ==1992], x = 'Model Year', hue='Company Name')
# Out:
# <Axes: xlabel='Model Year', ylabel='count'>

# %%
dataAux = data['Model Year'].value_counts(sort=True)
sns.barplot(y = dataAux.index.astype(str), x =dataAux, palette='deep' ).set(xlabel='Número de autos', ylabel='Año del modelo')
plt.title('Cantidad de autos por cada año')
# Out:
# Text(0.5, 1.0, 'Cantidad de autos por cada año')

# %% [markdown]
# # Preparando datos para predicción

# %%
data.head()
# Out:
#   Company Name Model Name    Price  Model Year   Location  Mileage
# 0       Toyota       Vitz  2385000        2017  Islamabad     9869  \
# 1       Toyota    Corolla   111000        2019        KPK    11111
# 2       Suzuki       Alto  1530000        2019        KPK    17500
# 3       Suzuki       Alto  1650000        2019     Punjab     9600
# 4       Toyota    Corolla  1435000        2010  Islamabad   120000
#
#   Engine Type  Engine Capacity   Color  Assembly  Body Type Transmission Type
# 0      Petrol             1000  Silver  Imported  Hatchback         Automatic  \
# 1      Petrol             1300   White     Local      Sedan         Automatic
# 2      Petrol              660   White     Local  Hatchback         Automatic
# 3      Petrol              660   White     Local  Hatchback            Manual
# 4      Petrol             1300   Black     Local      Sedan            Manual
#
#   Registration Status
# 0       Un-Registered
# 1          Registered
# 2       Un-Registered
# ...

# %%
data_4_prediction = data[['Price', 'Model Year', 'Mileage', 'Engine Capacity']]
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Company Name'], dtype=int)) 
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Location'], dtype=int)) 
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Engine Type'], dtype=int)) 
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Color'], dtype=int)) 
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Assembly'], dtype=int, drop_first=True)) # Eliminamos 'Imported' ya que es una relación binaria
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Body Type'], dtype=int))
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Transmission Type'], dtype=int, drop_first=True)) # Eliminamos 'Automatic' pues es una relación binaria
data_4_prediction = data_4_prediction.join(pd.get_dummies(data['Registration Status'], dtype=int).drop(['Un-Registered'], axis=1)) # Eliminamos 'Un-Registered' pues es una relación binaria
data_4_prediction
# Out:
#          Price  Model Year  Mileage  Engine Capacity  Adam  Audi  BMW  Chery
# 0      2385000        2017     9869             1000     0     0    0      0  \
# 1       111000        2019    11111             1300     0     0    0      0
# 2      1530000        2019    17500              660     0     0    0      0
# 3      1650000        2019     9600              660     0     0    0      0
# 4      1435000        2010   120000             1300     0     0    0      0
# ...        ...         ...      ...              ...   ...   ...  ...    ...
# 46017  3400000        2015    32000             1500     0     0    0      0
# 46018  2450000        2015    52000             1500     0     0    0      0
# 46019  3250000        2015   125000             1800     0     0    0      0
# 46020  3000000        2016    60000             1500     0     0    0      0
# 46021  2250000        2015    77000             1300     0     0    0      0
#
# ...

# %%
data_4_prediction.describe()
# Out:
#               Price    Model Year        Mileage  Engine Capacity
# count  4.602200e+04  46022.000000   46022.000000     46022.000000  \
# mean   2.014153e+06   2011.035374   90965.128243      1313.115575
# std    2.939071e+06      6.399403   63656.656034       614.690832
# min    1.110000e+05   1990.000000       1.000000        16.000000
# 25%    8.500000e+05   2007.000000   48899.500000      1000.000000
# 50%    1.450000e+06   2013.000000   80000.000000      1300.000000
# 75%    2.300000e+06   2016.000000  120000.000000      1500.000000
# max    7.750000e+07   2019.000000  999999.000000      6600.000000
#
#                Adam          Audi           BMW         Chery     Chevrolet
# count  46022.000000  46022.000000  46022.000000  46022.000000  46022.000000  \
# mean       0.000022      0.004520      0.002977      0.000174      0.000869
# std        0.004661      0.067076      0.054480      0.013183      0.029469
# ...

# %%
# plt.figure(figsize=(40,40))
# sns.heatmap(round(data_4_prediction.corr(),1), annot=True,  cmap='YlGnBu')

# %%
X = data_4_prediction.drop(['Price'], axis=1)
y = data_4_prediction['Price']

# %%
# Separar los datos en dos partes: Conjunto de entrenamiento y uno de pruebas
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit(X=X_ent, y=y_ent)
# Out:
# LinearRegression()

# %%
predicciones = modelo.predict(X_pru)

# %%
comparativa = {'Predicción' : predicciones, 'Valor Real': y_pru, 'Porcentaje': (predicciones-y_pru)/y_pru}
pd.DataFrame(comparativa)
# Out:
#          Predicción  Valor Real  Porcentaje
# 38746  2.230749e+06     2380000   -0.062711
# 28237  2.402027e+05      450000   -0.466216
# 19692  1.013881e+06      700000    0.448401
# 34819  1.131071e+06     1170000   -0.033273
# 16542  1.538866e+06     1175000    0.309673
# ...             ...         ...         ...
# 3770   5.187089e+06     5100000    0.017076
# 39146  3.325228e+06     3350000   -0.007395
# 29572  1.490290e+06     1100000    0.354809
# 28760  1.288066e+06      880000    0.463712
# 4635   2.050794e+05      450000   -0.544268
#
# [9205 rows x 3 columns]

# %%
print(modelo.score(X_ent, y_ent))
print(modelo.score(X_pru, y_pru))
# Out:
# 0.6286925951225129
# 0.6325050341848744

# %%
from sklearn.metrics import mean_absolute_error
preds = modelo.predict(X_pru)
mean_absolute_error(y_pru, preds)
# Out:
# 786535.2902682887

# %%
data.head()
# Out:
#   Company Name Model Name    Price  Model Year   Location  Mileage
# 0       Toyota       Vitz  2385000        2017  Islamabad     9869  \
# 1       Toyota    Corolla   111000        2019        KPK    11111
# 2       Suzuki       Alto  1530000        2019        KPK    17500
# 3       Suzuki       Alto  1650000        2019     Punjab     9600
# 4       Toyota    Corolla  1435000        2010  Islamabad   120000
#
#   Engine Type  Engine Capacity   Color  Assembly  Body Type Transmission Type
# 0      Petrol             1000  Silver  Imported  Hatchback         Automatic  \
# 1      Petrol             1300   White     Local      Sedan         Automatic
# 2      Petrol              660   White     Local  Hatchback         Automatic
# 3      Petrol              660   White     Local  Hatchback            Manual
# 4      Petrol             1300   Black     Local      Sedan            Manual
#
#   Registration Status
# 0       Un-Registered
# 1          Registered
# 2       Un-Registered
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_ent, y_ent)
# Out:
# RandomForestRegressor()

# %%
preds = forest.predict(X_pru)

# %%
forest.score(X_pru, y_pru)
# Out:
# 0.9522569809273081

# %%
from sklearn.metrics import mean_absolute_error
preds = forest.predict(X_pru)
mean_absolute_error(y_pru, preds)
# Out:
# 184585.5410748284
